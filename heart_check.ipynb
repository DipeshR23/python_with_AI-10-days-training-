# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
heart_df = pd.read_csv("C:\\Users\\acer\\OneDrive\\Desktop\\other\\heart_dataset.csv")
heart_df.head(7)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
# ...

# %%
heart_df.info()
heart_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ...

# %%
heart_df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
heart_df["HeartDisease"].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %% [markdown]
# ## making a seperate variables containg the ctg features and numerical features

# %%
numerical_features = heart_df.select_dtypes(include = ['int', 'float'])

# %%
numerical_features.head(3)
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0

# %%
ctg_features = heart_df.select_dtypes(include = ['object'])
ctg_features.head(5)
# Out:
#   Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# 0   M           ATA     Normal              N       Up
# 1   F           NAP     Normal              N     Flat
# 2   M           ATA         ST              N       Up
# 3   F           ASY     Normal              Y     Flat
# 4   M           NAP     Normal              N       Up

# %%
numerical_features.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
numerical_features.corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(numerical_features.corr(),annot =True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
for col in numerical_features.columns:
    sns.boxplot(data = numerical_features,x  = 'HeartDisease', y = col,hue = 'HeartDisease')
    plt.title(f"{col} vs heart disease")
    plt.show()

# %%
for col in ctg_features.columns:
    plt.figure(figsize = (5,4))
    sns.countplot(data = heart_df,x  = col,hue = 'HeartDisease')
    plt.title(f"{col} vs heart disease")
    plt.show()

# %% [markdown]
# ## visualize the categorical features

# %% [markdown]
# ## convert categorical data into numerical data

# %%
for col in ctg_features.columns:
    print("--------------------------------------")
    print(f"{ctg_features[col].value_counts() }")
# Out:
# --------------------------------------
# Sex
# M    725
# F    193
# Name: count, dtype: int64
# --------------------------------------
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64
# --------------------------------------
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64
# --------------------------------------
# ExerciseAngina
# N    547
# Y    371
# Name: count, dtype: int64
# --------------------------------------
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %% [markdown]
# ## for incoding

# %%
heart_df_model = pd.get_dummies(heart_df,columns = ctg_features.columns, drop_first = True , dtype= int)

# %%
heart_df_model
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
heart_df_model.columns.value_counts().sum()
# Out:
# np.int64(16)

# %%
heart_df_model.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
#
#    Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0      1                  1                  0                 0
# 1      0                  0                  1                 0
# 2      1                  1                  0                 0
# 3      0                  0                  0                 0
# 4      1                  0                  1                 0
#
#    RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# ...

# %%
x = heart_df_model.drop(columns =["HeartDisease"])

# %%
x
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_M  \
# 0     40        140          289          0    172      0.0      1
# 1     49        160          180          0    156      1.0      0
# 2     37        130          283          0     98      0.0      1
# 3     48        138          214          0    108      1.5      0
# 4     54        150          195          0    122      0.0      1
# ..   ...        ...          ...        ...    ...      ...    ...
# 913   45        110          264          0    132      1.2      1
# 914   68        144          193          1    141      3.4      1
# 915   57        130          131          0    115      1.2      1
# 916   57        130          236          0    174      0.0      0
# 917   38        138          175          0    173      0.0      1
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0                    1                  0                 0
# ...

# %%
y = heart_df_model["HeartDisease"]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2 , random_state = 42)

# %%
x_train.shape
# Out:
# (734, 15)

# %%
x_test.shape
# Out:
# (184, 15)

# %%
y_test.shape
# Out:
# (184,)

# %%
y_train.shape
# Out:
# (734,)

# %%
from sklearn.linear_model import LogisticRegression 
lr = LogisticRegression()

# %%
model = lr.fit(x_train, y_train)
model
# Out:
# C:\Users\acer\ml_training\ml10_days_env\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = model.predict(x_test)
predictions.shape
# Out:
# (184,)

# %%
result = pd.DataFrame({"actual":y_test, "predicted":predictions})

# %%
result
# Out:
#      actual  predicted
# 668       0          0
# 30        1          0
# 377       1          1
# 535       1          1
# 807       0          0
# ..      ...        ...
# 211       1          0
# 745       1          1
# 584       1          1
# 878       0          0
# 451       1          1
#
# [184 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
print(accuracy_score(y_test,predictions))
# Out:
# 0.8532608695652174

# %%
sns.heatmap(confusion_matrix(y_test,predictions) , annot= True)
plt.xlabel("predicted")
plt.ylabel("actual")
plt.show()

# %%
#new algo
from sklearn.svm import SVC
svc = SVC()

# %%
model2 = svc.fit(x_train,y_train)
model2
# Out:
# SVC()

# %%
predictions2 = model2.predict(x_test)
print(accuracy_score(y_test,predictions2))
# Out:
# 0.6847826086956522

# %%
# from sklearn import RandomForestClassifier

# %%
#for save model 
pip install joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import joblib

# %%
joblib.dump(model,"logistic_regression_model.pkl")
# Out:
# ['logistic_regression_model.pkl']

# %%
#load model
loaded_model = joblib.load("logistic_regression_model.pkl")
